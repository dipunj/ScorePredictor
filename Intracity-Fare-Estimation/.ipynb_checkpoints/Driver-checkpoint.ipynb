# %%
import numpy as np
import pandas as pd
from sklearn import neural_network
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
ann = neural_network.MLPRegressor(shuffle=True,
                                  alpha=0.5,
                                  hidden_layer_sizes=(100, 100),
                                  max_iter=10000,
                                  random_state=100,
                                  verbose=True)

# %%
def crossValidate(X, y, ann):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    
    clf.fit(X_train, y_train)
    prediction = clf.predict(X_test)
    
    print("CV performance")
    print(200 * r2_score(y_test, prediction))
    print("Train performance")
    print(200 * r2_score(y_train, clf.predict(X_train)))

# %%
def testRUN_crCsv(X, y, clf):
    
    scaler.fit(X)
    X = scaler.transform(X)
    
    clf.fit(X, y)
    
    predict = clf.predict(scaler.transform(test))
    
    predict = predict.round(decimals=2)
    predict = predict.reshape(predict.shape[0], 1)
    predict = np.concatenate([id_vec, predict], axis=1)
    predict = pd.DataFrame(data=predict, columns=['ID', 'FARE'])
    predict.to_csv("answer_neural.csv", index=False, header=True)

# %%
train = pd.read_csv('processed_train.csv')
test = pd.read_csv('processed_test.csv')
id_vec = np.array(test['ID'])

# %%
train.describe()
# Out:
#                  ID     TIMESTAMP  STARTING_LATITUDE  STARTING_LONGITUDE  \
# count  19662.000000  1.966200e+04       19662.000000        19662.000000
# mean    9999.227698  1.451398e+09           0.037223           -0.024111
# std     5770.145657  1.815150e+07           0.195358            0.210626
# min        1.000000  1.420058e+09          -0.270716           -0.384392
# 25%     5001.250000  1.435821e+09          -0.119660           -0.164897
# 50%     9990.500000  1.451196e+09          -0.003464           -0.003850
# 75%    14995.750000  1.467101e+09           0.168476            0.091658
# max    20000.000000  1.482944e+09           0.489475            0.367170
#
#        DESTINATION_LATITUDE  DESTINATION_LONGITUDE  VEHICLE_TYPE  \
# count          19662.000000           19662.000000  19662.000000
# mean               0.037342              -0.023330      3.003713
# std                0.194636               0.210757      1.997846
# min               -0.270713              -0.384384      0.000000
# 25%               -0.118605              -0.163232      1.000000
# 50%               -0.003495              -0.004159      3.000000
# 75%                0.168812               0.092015      5.000000
# max                0.489206               0.367120      6.000000
#
#        TOTAL_LUGGAGE_WEIGHT     WAIT_TIME  TRAFFIC_STUCK_TIME      ...       \
# count          19662.000000  19662.000000        19662.000000      ...
# mean             -67.313193    -69.009765           30.019225      ...
# std               52.211564     49.408524           21.913516      ...
# min             -100.000000   -100.000000            0.000000      ...
# 25%             -100.000000   -100.000000           12.000000      ...
# 50%             -100.000000   -100.000000           26.000000      ...
# 75%                4.000000      2.000000           45.000000      ...
# max               30.000000     19.000000           95.000000      ...
#
#                TIME       TIME_AM       weekday           bus          taxi  \
# count  19662.000000  19662.000000  19662.000000  19662.000000  19662.000000
# mean    1177.402604      0.500915      3.027057      0.437951      0.140016
# std      689.977743      0.500012      1.998239      0.496148      0.347013
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      569.250000      0.000000      1.000000      0.000000      0.000000
# 50%     1201.000000      1.000000      3.000000      0.000000      0.000000
# 75%     1754.000000      1.000000      5.000000      1.000000      0.000000
# max     2359.000000      1.000000      6.000000      1.000000      1.000000
#
#             cooling        public          city      mean_lat     mean_long
# count  19662.000000  19662.000000  19662.000000  19662.000000  19662.000000
# mean       0.431441      0.428542      2.473655     20.161530     79.763910
# std        0.495290      0.494880      1.732768      5.884635      5.076164
# min        0.000000      0.000000      0.000000     13.000000     72.500000
# 25%        0.000000      0.000000      1.000000     13.000000     77.000000
# 50%        0.000000      0.000000      2.000000     19.500000     77.500000
# 75%        1.000000      1.000000      4.000000     25.500000     83.000000
# max        1.000000      1.000000      5.000000     28.500000     88.500000
#
# [8 rows x 25 columns]

# %%
# Features to drop

drop_labels = ['ID', 'mean_lat', 'mean_long', 'TIME_AM','YEAR', 'TIMESTAMP']
train.drop(drop_labels, axis=1, inplace=True)
test.drop(drop_lables, axis=1, inplace=True)

# %%
X = train.drop(['FARE'], axis=1)
y = train['FARE']

# %%
# Hyperparameter tuning

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(ann,
            param_grid={
                'hidden_layer_sizes': [(8), (10),(10, 10, 10), (70, 50, 20), (15, 15, 15), (40, 40, 40)],
                'random_state': [100, 1000, 10000],
                'alpha': [0.01, 0.1, 1.0]
            },
            n_jobs=-1,
            scoring=make_scorer(r2_score),
            verbose=5)

gs.fit(X, y)
print("best estimator :\n",gs.best_estimator_)
print("Best parameters :\n",gs.best_params_)
print("CV RESULTS : \n",gs.cv_results_)

# %%
# CROSS VALIDATION code
crossValidate(X, y, ann)
#  Real testing
testRUN_crCsv(X, y, ann)
